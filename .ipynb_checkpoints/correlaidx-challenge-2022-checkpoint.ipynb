# %%
# packages
#pip install neo4j-driver
#pip install openpyxl
#pip install itertools

# %%
# imports
from neo4j import GraphDatabase, basic_auth
import pandas as pd
from openpyxl import Workbook, load_workbook
from itertools import islice

# %%
# set driver connection
driver = GraphDatabase.driver(
  "neo4j://3.239.242.97",
  auth=basic_auth("neo4j", "salute-capability-hooks"))

# %%
# define query functions
def name_query(name):
    cypher_query = '''
    MATCH (a:Officer {name:$name})-[r:officer_of|intermediary_of|registered_address*..10]-(b)
    RETURN b.name as name, b.node_id as node_id LIMIT 20
    '''
    with driver.session(database="neo4j") as session:
        results = session.execute_read(lambda tx: tx.run(cypher_query, name=name).data())
        print(f'{name}: {len(results)} results')
        driver.close()


def city_query(city):
    cypher_query = f'''
    MATCH (b)
    WHERE toLower(b.name) CONTAINS toLower(" {city} ")
    RETURN  *
    '''
    with driver.session(database="neo4j") as session:
        results = session.execute_read(lambda tx: tx.run(cypher_query).data())
        print(f'{city}: {len(results)} results')
        driver.close()

# %%
# import excel file (.xlsx)
book = load_workbook("Rechercheliste_Niedersachsen.xlsx")
sheet = book.active

data = sheet.values
cols = next(data)[1:]
data = list(data)
idx = [r[0] for r in data]
data = (islice(r, 1, None) for r in data)

# convert worksheet to a Dataframe
df = pd.DataFrame(data, index=idx, columns=cols)
df.head()
# Out:
#                             Geburtsdatum                     Wohnort (vmtl.)  \
# Martin Kind          1944-04-28 00:00:00                           Burgwedel
# Kind GmbH & Co. KG                  None                                None
# Dirk Roßmann         1976-09-07 00:00:00  Wittenbecksweg 20, 29646 Bispingen
# Raoul Roßmann        1986-08-10 00:00:00       Blücherstr. 5, 30175 Hannover
# Dirk Daniel Roßmann  1976-07-23 00:00:00       Riethof 6 B, 30916 Isernhagen
#
#                                                     Firmensitz   NaN   NaN  \
# Martin Kind                                               None  None  None
# Kind GmbH & Co. KG   Kokenhorststraße 3-5, 30938 Großburgwedel  None  None
# Dirk Roßmann                                              None  None  None
# Raoul Roßmann                                             None  None  None
# Dirk Daniel Roßmann                                       None  None  None
#
#                       NaN
# Martin Kind          None
# Kind GmbH & Co. KG   None
# Dirk Roßmann         None
# Raoul Roßmann        None
# Dirk Daniel Roßmann  None

# %%
# run query for names
query_list_names = ["Berlusconi"] # list of names
for name in query_list_names:
    name_query(name)
# Out:
# Berlusconi: 0 results

# %%
# run query for cities
query_list_cities = ["Bremen"] # list of cities
for city in query_list_cities:
    city_query(city)
# Out:
# Bremen: 31 results
# Hamburg: 226 results

# %%
query_list_cities = ["Hannover"] # list of cities
for city in query_list_cities:
    city_query(city)
# Out:
# Hannover: 23 results

# %%
query_major_cities = ["Hannover", "Bremen", "Hamburg", "Berlin", "Kiel"]

for city in query_major_cities:
    print(city_query(city))
# Out:
# Hannover: 23 results
# None
# Bremen: 31 results
# None
# Hamburg: 226 results
# None
# Berlin: 140 results
# None
# Kiel: 5 results
# None

# %%
wohnort = df.iloc[: ,1]
wohnort
# Out:
# Martin Kind                                             Burgwedel
# Kind GmbH & Co. KG                                           None
# Dirk Roßmann                   Wittenbecksweg 20, 29646 Bispingen
# Raoul Roßmann                       Blücherstr. 5, 30175 Hannover
# Dirk Daniel Roßmann                 Riethof 6 B, 30916 Isernhagen
#                                               ...
# Hans Georg Näder                                       Duderstadt
# Georgia Maria Näder                                    Duderstadt
# Julia Näder                                           Eckernförde
# Ottobock SE & Co. KGaA                                       None
# Näder Holding GmbH & Co. KG                                  None
# Name: Wohnort (vmtl.), Length: 136, dtype: object

# %%
cities = []
for x in wohnort:
    if x is not None and cities.count(x) == 0:
        cities.append(x)
#cities

# %%
# run query for cities
# cities # list of cities
for city in cities:
    city_query(city)
# Out:
# Burgwedel: 0 results
# Wittenbecksweg 20, 29646 Bispingen: 0 results
# Blücherstr. 5, 30175 Hannover: 0 results
# Riethof 6 B, 30916 Isernhagen: 0 results
# Hannover, München, Starnberg: 0 results
# Wedemark (Bissendorf), Hannover: 0 results
# An der Dörbrake 5, 29690 Schwarmstedt (Bothmer): 0 results
# Kiefernbrink 1, 38640 Goslar (Hahndorf): 0 results
# Hindenburgstraße 6 oder 7,30175 Hannover: 0 results
# Eichhornweg, 30900 Wedemark (Bissendorf): 0 results
# Hannover: 23 results
# Braunstraße 8, 30169 Hannover: 0 results
# Esseler Str. 12, 29690 Schwarmstedt: 0 results
# Verden/Aller: 0 results
# Leer: 7 results
# Süttorf: 0 results
# Meppen: 0 results
# Dissen: 0 results
# An der Bäke 9, 49377 Vechta-Calveslage: 0 results
# Burgdorf: 0 results
# Hannover, Isernhagen, Zürich: 0 results
# Damme, Königstein (Taunus): 0 results
# Hannover, Monaco: 0 results
# Beinhorn: 0 results
# Hannover, Gmunden: 0 results
# Papenburg: 0 results
# Ludwigsburg: 1 results
# Hermannsburg: 0 results
# Osnabrück: 0 results
# Bad Rothenfelde: 0 results
# Versmold: 0 results
# Theodor-Heuss-Str. 59, 48480 Spelle: 0 results
# Bernard-Krone-Str. 9, 48480 Spelle: 0 results
# Einbeck, Celle: 0 results
# Göttingen: 0 results
# Braunschweig: 6 results
# Waldstr. 22, 49086 Osnabrück: 0 results
# Frechener Weg 56, 50859 Köln: 0 results
# Aurich, Uetze-Dedenhausen: 0 results
# Rastdorf: 0 results
# Visbek: 4 results
# Vaduz: 84 results
# Wolfenbüttel: 0 results
# Bürgermeister-Peters-Str. 30, 37154 Northeim: 0 results
# München: 0 results
# Bovenden: 0 results
# Riemerling: 0 results
# Gestüt Brümmerhof, 29614 Soltau: 0 results
# Duderstadt: 0 results
# Eckernförde: 0 results

# %%
#personen = df.iloc[: ,0]
personen = ["Martin Kind", "Dirk Roßmann", "Raoul Roßmann", "Dirk Daniel Roßmann"]
personen

# run query for names
for name in personen:
    name_query(name)
# Out:
# Martin Kind: 0 results
# Dirk Roßmann: 0 results
# Raoul Roßmann: 0 results
# Dirk Daniel Roßmann: 0 results

# %%
#for row in data_top.index:
#    print(row, end = " ")
    
allPersons = list(df.index)
allPersons
# Out:
# ['Martin Kind',
#  'Kind GmbH & Co. KG',
#  'Dirk Roßmann',
#  'Raoul Roßmann',
#  'Dirk Daniel Roßmann',
#  'Rossmann',
#  'Carsten Maschmeyer',
#  'MM Vermögensverwaltungs GmbH & Co.KG \nc/o Maschmeyer Group',
#  'Klaus Meine',
#  'Scorpions GbR',
#  'Rudolf Schenker',
#  'Scorpions Musikproduktions- und Verlagsgesellschaft mbH',
#  'Sigmar Gabriel',
#  'Gerhard Schröder',
#  'Frank Hanebuth',
#  'Götz von Fromberg ',
#  'Albert Ehrich',
#  'Madjid (Madschid) Samii',
#  'Amir Samii',
#  'INI International Neuroscience Institute Hannover GmbH',
#  'Günter Papenburg',
#  'GP Günter Papenburg AG',
#  'Martin Weiß',
#  'ZAG Zeitarbeits-Gesellschaft GmbH Hannover',
#  'Utz Claassen ',
#  'Syntellix AG',
#  'Tina Voß',
#  'Tina Voß GmbH',
#  'Andreas Sennheiser',
#  'Daniel Sennheiser',
#  'Sennheiser GmbH & Co. KG',
#  'Jürgen Focke',
#  'Doris Focke',
#  'Focke & Co. (GmbH & Co. KG)',
#  'Wilhelm Carl Klopp',
#  'Insa Änne Klopp',
#  'Bünting-Gruppe / J. Bünting Beteiligungs AG',
#  'Franz-Josef Rothkötter',
#  'Franz-Josef Rothkötter GmbH & Co. KG\nRothkötter Mischfutterwerk GmbH',
#  'Klaus Hellmann',
#  'Jost Hellmann',
#  'Hellmann Worldwide Logistics SE & Co. KG',
#  'Dieter Fuchs',
#  'Alexander Manfred Fuchs',
#  'Fuchs Gewürze GmbH',
#  'Bernhard (Bernd) Meerpohl',
#  'Big Dutchman AG',
#  'Werner M. Bahlsen',
#  'Bahlsen GmbH Co. KG',
#  'Axel Bree',
#  'Philipp Bree',
#  'Mirko Slomka, Hannover\xa0',
#  'Michael Frenzel',
#  'Elmar Degenhart',
#  'Johann Bunte Bauunternehmung SE & Co. KG',
#  'Philipp Rösler',
#  'Bernard große Broermann',
#  'Ernst August von Hannover\xa0(Vater)',
#  'Stefan Homburg\xa0',
#  'Ursula von der Leyen',
#  'Ernst Albrecht',
#  'Ernst August von Hannover\xa0(Sohn)',
#  'Bernard Meyer',
#  'Jan Meyer',
#  'Tim Meyer',
#  'Paul Meyer',
#  'Meyer Werft GmbH & Co. KG',
#  'Meyer Werft Verwaltungs-GmbH',
#  'Meyer Neptun GmbH',
#  'Friedhelm Behn',
#  'CBR Fashion Holding',
#  'CBR Service GmbH',
#  'Bastian Müller',
#  'Hans-Heiner Müller',
#  'WM SE (Wessels + Müller AG)',
#  'Heinrich W. Risken',
#  'Arno Risken',
#  'Oliver H. W. Risken',
#  'Heristo AG',
#  'Bernard Krone (Sohn)',
#  'Nicola Krone',
#  'Dorothee Renzelmann',
#  'Bernard Krone Vater)',
#  'Bernard Krone Holding SE & Co. KG',
#  'Gunnar Felix Büchting',
#  'Andreas J. Büchting',
#  'KWS Saat SE & Co. KGaA',
#  'Friedrich Georg Knapp',
#  'New Yorker Group Services International GmbH & Co. KG',
#  'Hans-Michael Gallenkamp',
#  'Anita Schoeller',
#  'Hans-Christoph Gallenkamp',
#  'Felix Schoeller Gruppe',
#  'Bernhard Aloys Wobben',
#  'Simon-Hermann Wobben',
#  'Enercon GmbH',
#  'Ferit Özgör',
#  'Bedirhan Özgör',
#  'Bedran Resso Özgör',
#  'Deniz Örgör',
#  'Recep Örgör',
#  'Davut Özgör',
#  'EW Group GmbH (Erich Wesjohann GmbH & Co. KG)',
#  'Erich Wesjohann',
#  'Dirk Wesjohann',
#  'Jan Wesjohann',
#  'Paul-Heinz Westjohann',
#  'PHW-Gruppe',
#  'Annegret Wesjohann',
#  'Peter Wesjohann',
#  'Doris Wesjohann',
#  'Martin Batliner',
#  'Florian Rehm',
#  'Christina Flügel',
#  'Christina Stangl',
#  'Andreas Kreuter',
#  'Mast-Jägermeister SE',
#  'Claudia-Susan Buschke',
#  'Karin Sartorius-Herbst',
#  'Theresia Herbst',
#  'Erbengemeinschaft Horst Walter Sartorius',
#  'Sartorius-Herbst Verwaltungs GmbH',
#  'Ulrike Baro',
#  'Sartorius AG',
#  'Walter Franken',
#  'Andreas Franken',
#  'Kai-Christian Franken',
#  'Britta Franken',
#  'Christine Franken',
#  'Gregor L. Baum',
#  'Julia Baum',
#  'Hans Georg Näder',
#  'Georgia Maria Näder',
#  'Julia Näder',
#  'Ottobock SE & Co. KGaA',
#  'Näder Holding GmbH & Co. KG']

# %%
for name in allPersons:
    name_query(name)
# Out:
# Martin Kind: 0 results
# Kind GmbH & Co. KG: 0 results
# Dirk Roßmann: 0 results
# Raoul Roßmann: 0 results
# Dirk Daniel Roßmann: 0 results
# Rossmann: 0 results
# Carsten Maschmeyer: 0 results
# MM Vermögensverwaltungs GmbH & Co.KG
# c/o Maschmeyer Group: 0 results
# Klaus Meine: 0 results
# Scorpions GbR: 0 results
# Rudolf Schenker: 0 results
# Scorpions Musikproduktions- und Verlagsgesellschaft mbH: 0 results
# Sigmar Gabriel: 0 results
# Gerhard Schröder: 0 results
# Frank Hanebuth: 0 results
# Götz von Fromberg : 0 results
# Albert Ehrich: 0 results
# Madjid (Madschid) Samii: 0 results
# Amir Samii: 0 results
# INI International Neuroscience Institute Hannover GmbH: 0 results
# Günter Papenburg: 0 results
# GP Günter Papenburg AG: 0 results
# Martin Weiß: 0 results
# ZAG Zeitarbeits-Gesellschaft GmbH Hannover: 0 results
# Utz Claassen : 0 results
# Syntellix AG: 0 results
# Tina Voß: 0 results
# Tina Voß GmbH: 0 results
# Andreas Sennheiser: 0 results
# Daniel Sennheiser: 0 results
# Sennheiser GmbH & Co. KG: 0 results
# Jürgen Focke: 0 results
# Doris Focke: 0 results
# Focke & Co. (GmbH & Co. KG): 0 results
# Wilhelm Carl Klopp: 0 results
# Insa Änne Klopp: 0 results
# Bünting-Gruppe / J. Bünting Beteiligungs AG: 0 results
# Franz-Josef Rothkötter: 0 results
# Franz-Josef Rothkötter GmbH & Co. KG
# Rothkötter Mischfutterwerk GmbH: 0 results
# Klaus Hellmann: 0 results
# Jost Hellmann: 0 results
# Hellmann Worldwide Logistics SE & Co. KG: 0 results
# Dieter Fuchs: 0 results
# Alexander Manfred Fuchs: 0 results
# Fuchs Gewürze GmbH: 0 results
# Bernhard (Bernd) Meerpohl: 0 results
# Big Dutchman AG: 0 results
# Werner M. Bahlsen: 0 results
# Bahlsen GmbH Co. KG: 0 results
# Axel Bree: 0 results
# Philipp Bree: 0 results
# Mirko Slomka, Hannover : 0 results
# Michael Frenzel: 0 results
# Elmar Degenhart: 0 results
# Johann Bunte Bauunternehmung SE & Co. KG: 0 results
# Philipp Rösler: 0 results
# Bernard große Broermann: 0 results
# Ernst August von Hannover (Vater): 0 results
# Stefan Homburg : 0 results
# Ursula von der Leyen: 0 results
# Ernst Albrecht: 0 results
# Ernst August von Hannover (Sohn): 0 results
# Bernard Meyer: 0 results
# Jan Meyer: 0 results
# Tim Meyer: 0 results
# Paul Meyer: 0 results
# Meyer Werft GmbH & Co. KG: 0 results
# Meyer Werft Verwaltungs-GmbH: 0 results
# Meyer Neptun GmbH: 0 results
# Friedhelm Behn: 0 results
# CBR Fashion Holding: 0 results
# CBR Service GmbH: 0 results
# Bastian Müller: 0 results
# Hans-Heiner Müller: 0 results
# WM SE (Wessels + Müller AG): 0 results
# Heinrich W. Risken: 0 results
# Arno Risken: 0 results
# Oliver H. W. Risken: 0 results
# Heristo AG: 0 results
# Bernard Krone (Sohn): 0 results
# Nicola Krone: 0 results
# Dorothee Renzelmann: 0 results
# Bernard Krone Vater): 0 results
# Bernard Krone Holding SE & Co. KG: 0 results
# Gunnar Felix Büchting: 0 results
# Andreas J. Büchting: 0 results
# KWS Saat SE & Co. KGaA: 0 results
# Friedrich Georg Knapp: 0 results
# New Yorker Group Services International GmbH & Co. KG: 0 results
# Hans-Michael Gallenkamp: 0 results
# Anita Schoeller: 0 results
# Hans-Christoph Gallenkamp: 0 results
# Felix Schoeller Gruppe: 0 results
# Bernhard Aloys Wobben: 0 results
# Simon-Hermann Wobben: 0 results
# Enercon GmbH: 0 results
# Ferit Özgör: 0 results
# Bedirhan Özgör: 0 results
# Bedran Resso Özgör: 0 results
# Deniz Örgör: 0 results
# Recep Örgör: 0 results
# Davut Özgör: 0 results
# EW Group GmbH (Erich Wesjohann GmbH & Co. KG): 0 results
# Erich Wesjohann: 0 results
# Dirk Wesjohann: 0 results
# Jan Wesjohann: 0 results
# Paul-Heinz Westjohann: 0 results
# PHW-Gruppe: 0 results
# Annegret Wesjohann: 0 results
# Peter Wesjohann: 0 results
# Doris Wesjohann: 0 results
# Martin Batliner: 0 results
# Florian Rehm: 0 results
# Christina Flügel: 0 results
# Christina Stangl: 0 results
# Andreas Kreuter: 0 results
# Mast-Jägermeister SE: 0 results
# Claudia-Susan Buschke: 0 results
# Karin Sartorius-Herbst: 0 results
# Theresia Herbst: 0 results
# Erbengemeinschaft Horst Walter Sartorius: 0 results
# Sartorius-Herbst Verwaltungs GmbH: 0 results
# Ulrike Baro: 0 results
# Sartorius AG: 0 results
# Walter Franken: 0 results
# Andreas Franken: 0 results
# Kai-Christian Franken: 0 results
# Britta Franken: 0 results
# Christine Franken: 0 results
# Gregor L. Baum: 0 results
# Julia Baum: 0 results
# Hans Georg Näder: 0 results
# Georgia Maria Näder: 0 results
# Julia Näder: 0 results
# Ottobock SE & Co. KGaA: 0 results
# Näder Holding GmbH & Co. KG: 0 results
